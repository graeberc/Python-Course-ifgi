# %% [markdown]
# # Find hospitals closest to an incident.

# %% [markdown]
# This jupyter notebook constitutes the Exercise Sheet for the first lecture aput the arcgis API for Python.
# It is build as a 'gap text' challenge, there is a lot of text, code snippets and comments already added. To complete this exercise follow the instructions to build a fully working jupyter notebook. Add comments if necessary.
# You will use the functions of the network analyst module from the arcgis api for Python to build a solver the finds the route and the distance in kilometers towards the next hospital in Münster.
# There are two bonus challenges for 2 points each:
# 1. Build a Interactive Input for the Incident Coordinates
# 2. Label the result of the routing with the kilometer distance
#
# You will find the details for the bonus challenge in the explanations.
# There are 10 Points for the exercise and 4 bonus points available.
# Please remember to write code that is easy readable, well documented and actually working.
# The `network` module of the ArcGIS API for Python can be used to solve different types of network analysis operations. In this Exercise, we see how to find the hospital that is closest to an incident.

# %% [markdown]
# ## Closest facility

# %% [markdown]
# The closest facility solver provides functionality for finding out the closest locations to a particular input point. This solver would be useful in cases when you have an incident and need to find the closest facility or need to get information on the travel time and the distance to each of the facilities from an incident point for reporting purposes.
# (http://desktop.arcgis.com/en/arcmap/latest/extensions/network-analyst/GUID-96C273DB-6A24-4D42-AADA-975A33B44F3D-web.png)
# When finding closest facilities, you can specify how many to find and whether the direction of travel is toward or away from them. The closest facility solver displays the best routes between incidents and facilities, reports their travel costs, and returns driving directions.

# %% [markdown]
# ### Connect to your GIS
# As a first step, you would need to establish a connection to your organization which could be an ArcGIS Online organization or an ArcGIS Enterprise.

# %%
from IPython.display import HTML
import pandas as pd
from arcgis.gis import GIS
import getpass
#connect to your GIS
# please dont enter your password in clear letters, make sure you use getpass
#my_gis = GIS(url=, username = , password = )
pw = getpass.getpass() 
my_gis = GIS("https://www.arcgis.com", "ngrosseb_digicarto24", pw)
my_gis
# Out:
# ---------------------------------------------------------------------------
# ArcGISLoginError                          Traceback (most recent call last)
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:825, in Connection.get(self, path, params, **kwargs)
#     824     else:
# --> 825         resp = self._session.get(
#     826             url=url,
#     827             params=params,
#     828             cert=cert,
#     829             verify=self._verify_cert,
#     830             allow_redirects=allow_redirects,
#     831         )
#     832 except requests.exceptions.SSLError as err:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\auth\api.py:527, in EsriSession.get(self, url, **kwargs)
#     526 with self._handle_drop_auth(drop_auth=kwargs.pop("drop_auth", False)):
# --> 527     return self._session.get(
#     528         url, allow_redirects=redirects, proxies=proxies, **kwargs
#     529     )
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\requests\sessions.py:484, in Session.prepare_request(self, request)
#     483 p = PreparedRequest()
# --> 484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
#     490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\requests\models.py:371, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     370 self.prepare_body(data, files, json)
# --> 371 self.prepare_auth(auth, url)
#     373 # Note that prepare_auth must be last to enable authentication schemes
#     374 # such as OAuth to work on a fully prepared request.
#     375
#     376 # This MUST go after prepare_auth. Authenticators could add a hook
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\requests\models.py:602, in PreparedRequest.prepare_auth(self, auth, url)
#     601 # Allow auth to make its changes.
# --> 602 r = auth(self)
#     604 # Update self to reflect the auth changes.
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\auth\_auth\_token.py:858, in EsriBuiltInAuth.__call__(self, r)
#     857 if self.legacy == False:
# --> 858     r.headers["X-Esri-Authorization"] = f"Bearer {self.token}"
#     859 elif self.legacy and r.method == "GET":
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\auth\_auth\_token.py:845, in EsriBuiltInAuth.token(self)
#     844 except ArcGISLoginError as aex:
# --> 845     raise aex
#     846 except Exception as ex:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\auth\_auth\_token.py:840, in EsriBuiltInAuth.token(self)
#     839 if self._response_type == "token":
# --> 840     self._init_response_type_token()
#     841 else:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\auth\_auth\_token.py:618, in EsriBuiltInAuth._init_response_type_token(self)
#     617     message: str = ",".join(dict_object["messages"])
# --> 618     raise ArcGISLoginError(message=message)
#     619 callback_url = response.headers["location"]
#
# ArcGISLoginError: Invalid username or password.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 #connect to your GIS
#       6 # please dont enter your password in clear letters, make sure you use getpass
#       7 #my_gis = GIS(url=, username = , password = )
#       8 pw = getpass.getpass()
# ----> 9 my_gis = GIS("https://www.arcgis.com", "ngrosseb_digicarto24", pw)
#      10 my_gis
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\__init__.py:676, in GIS.__init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     670         raise RuntimeError(
#     671             "An untrusted SSL error occurred when attempting to connect to the provided GIS.\n"
#     672             "If you trust this server and want to proceed, add 'verify_cert=False' as an "
#     673             "argument when connecting to the GIS."
#     674         )
#     675     else:
# --> 676         raise e
#     677 try:
#     678     if (
#     679         url.lower().find("arcgis.com") > -1
#     680         and self._portal.is_logged_in
#     681         and self._portal.con._auth.lower() == "oauth"
#     682     ):
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\__init__.py:613, in GIS.__init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     611     self._expiration = 60
#     612 try:
# --> 613     self._portal = _portalpy.Portal(
#     614         self._url,
#     615         self._username,
#     616         self._password,
#     617         self._key_file,
#     618         self._cert_file,
#     619         proxy_host=self._proxy_host,
#     620         proxy_port=self._proxy_port,
#     621         verify_cert=self._verify_cert,
#     622         client_id=self._client_id,
#     623         expiration=self._expiration,
#     624         referer=self._referer,
#     625         custom_auth=custom_auth,  # token=self._utoken,
#     626         client_secret=client_secret,
#     627         trust_env=kwargs.get("trust_env", None),
#     628         timeout=self._timeout,
#     629         proxy=kwargs.get("proxy", None),
#     630         custom_adapter=custom_adapter,
#     631         token=self._utoken,
#     632         api_key=self._api_key,
#     633         is_hosted_nb_home=self._is_hosted_nb_home,
#     634         use_gen_token=self._use_gen_token,
#     635         security_kwargs=security_kwargs,
#     636         ca_bundles=ca_bundles,
#     637     )
#     638     if self._portal.is_kubernetes:
#     639         from .kubernetes._sharing import KbertnetesPy
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\_impl\_portalpy.py:240, in Portal.__init__(self, url, username, password, key_file, cert_file, expiration, referer, proxy_host, proxy_port, connection, workdir, tokenurl, verify_cert, client_id, custom_auth, token, **kwargs)
#     212         self.con = Connection(
#     213             baseurl=self.resturl,
#     214             tokenurl=tokenurl,
#    (...)
#     237             ca_bundles=self._ca_bundles,
#     238         )
#     239 # self.get_version(True)
# --> 240 self.get_properties(True)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\_impl\_portalpy.py:1305, in Portal.get_properties(self, force)
#    1303 with warnings.catch_warnings():
#    1304     warnings.simplefilter("ignore")
# -> 1305     resp = self.con.get(url, {"f": "json"})
#    1307 if resp:
#    1308     self._properties = resp
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:857, in Connection.get(self, path, params, **kwargs)
#     853     raise requests.exceptions.RequestException(
#     854         "A general exception was raised: %s" % errRE
#     855     )
#     856 except Exception as e:
# --> 857     raise Exception("A general error occurred: %s" % e)
#     858 except:
#     859     import traceback
#
# Exception: A general error occurred: Invalid username or password.

# %% [markdown]
# ### Create a Network Layer
# To perform any network analysis (such as finding the closest facility, the best route between multiple stops, or service area around a facility), you would need to create a `NetworkLayer` object. In this sample, since we are solving for closest facilities, we need to create a `ClosestFacilityLayer` which is a type of `NetworkLayer`.
# To create any `NetworkLayer` object, you would need to provide the URL to the appropriate network analysis service. Hence, in this sample, we provide a `ClosestFacility` URL to create a `ClosestFacilityLayer` object.
# Since all ArcGIS Online organizations already have access to those routing services, you can access this URL through the `GIS` object's `helperServices` property. If you have your own ArcGIS Server based map service with network analysis capability enabled, you would need to provide the URL for this service.
# Let us start by importing the `network` module

# %%
import arcgis.network as network

# %% [markdown]
# Access the analysis URL from the `GIS` object

# %%
analysis_url = my_gis.properties.helperServices.closestFacility.url
analysis_url
# Out:
# 'https://route.arcgis.com/arcgis/rest/services/World/ClosestFacility/NAServer/ClosestFacility_World'

# %% [markdown]
# Create a `ClosestFacilityLayer` object using this URL
# See the help for details in Syntax. https://developers.arcgis.com/python/api-reference/arcgis.network.toc.html#closestfacilitylayer

# %%
cf_layer = network.ClosestFacilityLayer(analysis_url, gis=my_gis)

# %% [markdown]
# ### Create hospitals layer
# In this sample, we will be looking for the closest hospital (facility) to an incident location. Even though we are interested in finding out the closest one, it would still be helpful to get the information on the distance and travel time to all of them for reference purposes.
# In the code below, we need to geocode the hospitals' addresses as well as do the reverse geocode for the incident location which has been supplied in the latitude/longitude format.
# To perform the geocode operations, we import the `geocoding` module of the ArcGIS API.

# %%
from arcgis import geocoding

# %% [markdown]
# In this sample, we geocode addresses of hospitals to create the facility layer. In your workflows, this could any feature layer. Create a list of hospitals in Münster, Germany

# %%
hospitals_addresses = ['Dorbaumstraße 300, 48157 Münster, Germany',
                       'Alexianerweg 9, 48163 Münster, Germany',
                       'Westfalenstr. 109, 48165 Münster, Germany',
                       'Loerstraße 23, 48143 Münster, Germany',
                       'Hohenzollernring 70, 48145 Münster, Germany',
                       'Wichernstraße 8, 48147 Münster, Germany',
                       'Domagkstr. 5, 48149 Münster, Germany']

# %% [markdown]
# Loop through each address and geocode it. The geocode operation returns a list of matches for each address. We pick the first result and extract the coordinates from it and construct a `Feature` object out of it. Then we combine all the `Feature`s representing the hospitals into a `FeatureSet` object.
# Geocoding syntax: https://developers.arcgis.com/python/api-reference/arcgis.geocoding.html#geocode
# Feature Syntax: https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#feature
# Feature Set Syntax: https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#featureset
# Hint: Check the structure from the return element of the geocoder to properly construct your feature. Use a loop to run through the list of adresses, add each result feature to a python list and use this python list to build your feature set. While building the feature set, use this as the value for the spatial_reference parameter `{'wkid' : 4326, 'latestWkid': 4326}`

# %%
from arcgis.features import Feature, FeatureSet

# %%
hosp_feat_list = []
for address in hospitals_addresses:
    hit = geocoding.geocode(address)[0]# best match for this address
    geom = hit["location"]
    geom["spatialReference"] = {"wkid": 4326, "latestWkid": 4326}
    feat = Feature(geometry=geom, attributes=hit["attributes"])
    hosp_feat_list.append(feat) # collect them

# %% [markdown]
# Construct a `FeatureSet` using each hospital `Feature`.

# %%
hospitals_fset = FeatureSet(
    hosp_feat_list,
    geometry_type="esriGeometryPoint",
    spatial_reference={"wkid": 4326, "latestWkid": 4326} # given in the notebook
)

# %% [markdown]
# Lets draw our hospitals on a map. To do so, intanciate a gis.map object, focused in Münster. Set the basemap to `arcgis-light-gray`
#
# Details about the map widget can be found here https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.GIS.map
# use the map.draw() function to add the hospitals to the map. You can use the following value for the 'symbol' parameter: `{\"type\": \"esriSMS\",\"style\": \"esriSMSSquare\",\"color\": [76,115,0,255],\"size\": 8,}`

# %%
from IPython.display import HTML

# %%
# instanciate the map
map1 = my_gis.map("Münster, Germany")
map1.zoom = 12
map1.basemap.basemap = "arcgis-light-gray" # the basemap the notebook specifies
map1 # display the widget (must be the LAST line)
# Out:
# Map()

# %%
from arcgis.map.symbols import SimpleMarkerSymbolEsriSMS, SimpleLineSymbolEsriSLS, SimpleMarkerSymbolStyle, SimpleLineSymbolStyle

# Draw the hospitals on the map as green squares.
# NOTE: the custom symbol must be passed via `drawing_info` (NOT `options`),
# otherwise the map falls back to the default pink markers.
hospital_drawing_info = {
    "renderer": {
        "type": "simple",
        "symbol": {
            "type": "esriSMS",
            "style": "esriSMSSquare",
            "color": [76, 115, 0, 255],
            "size": 8,
            "outline": {
                "color": [255, 255, 255, 255],  # crisp white border
                "width": 1,
                "type": "esriSLS",
                "style": "esriSLSSolid"
            }
        }
    }
}
map1.content.add(hospitals_fset, drawing_info=hospital_drawing_info)

# %% [markdown]
# ### Create incidents layer
# Lets use the geocoding.reverse_geocoding function to build an Feature set from the provided incident coordinates. Feel free to use your own coordinates or use the one provided
# The syntax for the reverse geocoding is here: https://developers.arcgis.com/python/api-reference/arcgis.geocoding.html#reverse-geocode
# 1. Reverse Geocode the coordinates
# 2. build a arcgis.Feature from the result object, using the 'location' from the response object as a parameter for the `geometry` parameter and the 'adress' from the response object for the `attributes` parameter of the Feature.
# 3. Build a Feature set from the one Feature, similar to the feature set for the hospitals. You can use the same spatial_reference parameter

# %% [markdown]
# ## Bonus Challenge: Build an interactive Input for the coordinates
# for 2 extra points:
# Open an input form and verify that the input string has the format of XX.XXXX, YY.YYYY
# Give Feedback to the user if the format is correct or not.

# %%
import re

# Prompt user for input
user_input = input("Enter incident coordinates (Format: Lon,Lat -> e.g., 7.6413,51.9530): ").strip()

# Validate input matches float,float pattern using regular expressions
pattern = r"^-?\d+\.\d+,\s*-?\d+\.\d+$"
if re.fullmatch(pattern, user_input):
    print("Success: Coordinate format is valid!")
    incident_coords = user_input
else:
    print("Format Error: Expected format 'XX.XXXX, YY.YYYY'. Falling back to default Münster incident coordinates.")
    incident_coords = '7.641378810646356,51.95304243253929'

# 1. reverse geocode the coordinates
lon, lat = [float(v) for v in incident_coords.split(",")]
hit = geocoding.reverse_geocode({"x": lon, "y": lat, "spatialReference": {"wkid": 4326}})
# 2. build a Feature — 'location' for geometry, 'address' for attributes (as instructed)
incident_feat = Feature(geometry=hit["location"], attributes=hit["address"])
# 3. wrap the single Feature in a FeatureSet (same spatial reference as before)
incident_fset = FeatureSet([incident_feat],
 geometry_type="esriGeometryPoint",
 spatial_reference={"wkid": 4326, "latestWkid": 4326})
# Out:
# Success: Coordinate format is valid!

# %%
# check for the result (this cell does not need to be changed)
incident_fset.features
# Out:
# [{"geometry": {"x": 7.641539219517, "y": 51.952985750765, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "Dortmunder Stra\u00dfe 34, 48155, M\u00fcnster, Mitte-Nordost, Mauritz, Nordrhein-Westfalen", "LongLabel": "Dortmunder Stra\u00dfe 34, 48155, M\u00fcnster, Mitte-Nordost, Mauritz, Nordrhein-Westfalen, DEU", "ShortLabel": "Dortmunder Stra\u00dfe 34", "Addr_type": "PointAddress", "Type": "", "PlaceName": "", "AddNum": "34", "Address": "Dortmunder Stra\u00dfe 34", "Block": "", "Sector": "", "Neighborhood": "Mauritz", "District": "Mitte-Nordost", "City": "M\u00fcnster", "MetroArea": "", "Subregion": "M\u00fcnster", "Region": "Nordrhein-Westfalen", "RegionAbbr": "NW", "Territory": "", "Postal": "48155", "PostalExt": "", "CntryName": "Deutschland", "CountryCode": "DEU", "X": 7.641539219517, "Y": 51.952985750765, "InputX": 7.6413, "InputY": 51.953, "StrucType": "", "StrucDet": "", "OBJECTID": 1}}]

# %% [markdown]
# Draw the incident Feature Set on the map, using this value for the 'symbol' parameter `{\"type\": \"esriSMS\",\"style\": \"esriSMSCircle\",\"color\": [255,0,0,255],\"size\": 8}`

# %%
# draw the incidents on the existing map widget
# Draw the incident as a red circle (symbol as specified in the notebook).
# The symbol is passed via `drawing_info` so it is actually applied.
incident_drawing_info = {
    "renderer": {
        "type": "simple",
        "symbol": {
            "type": "esriSMS",
            "style": "esriSMSCircle",
            "color": [255, 0, 0, 255],  # red, as required
            "size": 8,                   # size 8, as required
            "outline": {
                "color": [255, 255, 255, 255],
                "width": 1,
                "type": "esriSLS",
                "style": "esriSLSSolid"
            }
        }
    }
}
map1.content.add(incident_fset, drawing_info=incident_drawing_info)

# %% [markdown]
# ## Solve for closest hospital
# Now, you can solve the closest facility layer you created in the beginning. Syntax: https://developers.arcgis.com/python/api-reference/arcgis.network.toc.html#closestfacilitylayer
# Use your incidents feature set for the `incidents` parameter, your hospital feature set for the `facilities` parameter.
# Set the `default_target_facility_count` parameter to 1, since we only want to see the routing to the closest hospital
# Set the remaining attributes in a way that the impedance is set to travel time and the travel distance is added in kilometers

# %%
# solve your closest facillity layer
result = cf_layer.solve_closest_facility(
 incidents=incident_fset,
 facilities=hospitals_fset,
 default_target_facility_count=1,
 impedance_attribute_name="TravelTime",
 accumulate_attribute_names=["Kilometers"],
 return_cf_routes=True
)

# %% [markdown]
# Let us inspect the result dictionary. You will use the content of the `routes` dictionary to create the line to be plotted on the map. you can keep the following 3 Code Cells as is, without doing anything

# %%
result.keys()
# Out:
# dict_keys(['requestID', 'routes', 'messages'])

# %% [markdown]
# Let us use the `routes` dictionary to construct line features out of the routes to display on the map

# %%
result['routes'].keys()
# Out:
# dict_keys(['fieldAliases', 'geometryType', 'spatialReference', 'fields', 'features'])

# %%
result['routes']['features'][0].keys()
# Out:
# dict_keys(['attributes', 'geometry'])

# %% [markdown]
# From here, you need to continue to modify the code
# Construct line features out of the routes that are returned.
# The process is the same as before.
# Build a `Feature` for each route (there yould only be one)
# Add this to a result list
# Build a `FeatureSet` from the list

# %%
# build the list with features
line_feat_list = []
for line_dict in result["routes"]["features"]:
 f = Feature(geometry=line_dict["geometry"], attributes=line_dict["attributes"])
 line_feat_list.append(f)

# %%
# create a feature set
routes_fset = FeatureSet(features=line_feat_list,
    geometry_type="esriGeometryPolyline", # a LINE this time, not a point
    spatial_reference={"wkid": 4326, "latestWkid": 4326})

# %% [markdown]
# Add the routes back to the map using the `draw` method of the map widget once again. Make sure to scroll back up to verify the result
# You can use this value for the symbol parameter `{'type': 'esriSLS', 'style': 'esriSLSSolid','color': [0,0,255,100], 'width': 6}`

# %%
# draw the result to the map
# Draw the blue routing line on the map.
# The line symbol is passed via `drawing_info` so it is actually applied.
route_drawing_info = {
    "renderer": {
        "type": "simple",
        "symbol": {
            "type": "esriSLS",
            "style": "esriSLSSolid",
            "color": [0, 0, 255, 100],  # semi-transparent blue
            "width": 6
        }
    }
}
map1.content.add(routes_fset, drawing_info=route_drawing_info)

# %% [markdown]
# ## Bonus Challenge
# for 2 Extra Points: Label the drawn Line with the distance value from the result object

# %%
# optional bonus content

# %%
# --- Bonus 2: label the already drawn route line with its distance in kilometers ---

# 1. Read the accumulated kilometre distance from the route's own attributes.
#    accumulate_attribute_names=["Kilometers"] produces a 'Total_Kilometers' field.
#    We look the field up dynamically so a differing name still works.
route_attrs = routes_fset.features[0].attributes
dist_key = next((k for k in route_attrs if "kilometer" in k.lower()), "Total_Kilometers")
raw_distance = route_attrs.get(dist_key, 0)
rounded_distance = f"{round(raw_distance, 1)} km"
print(f"Distance field '{dist_key}' -> {rounded_distance}")

# 2. Pick a point roughly in the middle of the route line to anchor the label on.
route_path = routes_fset.features[0].geometry["paths"][0]
mid_x, mid_y = route_path[len(route_path) // 2]
label_point = {"x": mid_x, "y": mid_y,
               "spatialReference": {"wkid": 4326, "latestWkid": 4326}}
label_feat = Feature(geometry=label_point, attributes={"distance": rounded_distance})
label_fset = FeatureSet([label_feat],
                        geometry_type="esriGeometryPoint",
                        spatial_reference={"wkid": 4326, "latestWkid": 4326})

# 3. Draw the distance as a text label on top of the existing blue route line
#    (the route itself is already drawn above, so we do NOT add it again).
#    The symbol is passed via `drawing_info` so it is actually applied.
label_drawing_info = {
    "renderer": {
        "type": "simple",
        "symbol": {
            "type": "esriTS",
            "text": rounded_distance,
            "color": [0, 0, 0, 255],
            "haloColor": [255, 255, 255, 255],
            "haloSize": 1,
            "font": {"size": 12, "weight": "bold"},
            "yoffset": 8,
        }
    }
}
map1.content.add(label_fset, drawing_info=label_drawing_info)
# Out:
# Distance field 'Total_Kilometers' -> 1.1 km

# %% [markdown]
# ## View the map in VS Code
# VS Code cannot render the interactive ArcGIS map widget (a known `anywidget` frontend limitation), so the map cells above execute correctly but stay blank.
#
# To still see the completed result (hospitals, incident and the solved route) inside this workflow, we export the current state of `map1` to a standalone HTML file. Open that file in any web browser to inspect the map.

# %%
# Export the finished map to a standalone HTML file so it can be viewed in VS Code / any browser.
# This works around the fact that the interactive widget does not render inside VS Code.
import os

output_html = os.path.join(os.getcwd(), "muenster_closest_hospital_map.html")
map1.export_to_html(output_html, title="Closest Hospital Route - Münster")

print(f"Map exported to: {output_html}")
print("Open this HTML file in a web browser to view the hospitals, incident and route.")
# Out:
# Map exported to: c:\Users\nilsg\repos\Python-Course-ifgi\exercise_12\muenster_closest_hospital_map.html
# Open this HTML file in a web browser to view the hospitals, incident and route.
